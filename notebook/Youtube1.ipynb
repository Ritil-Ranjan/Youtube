# %% [markdown]
# <a href="https://colab.research.google.com/github/Ritil-Ranjan/Youtube/blob/main/Youtube1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from googleapiclient.discovery import build
import pandas as pd

# %%
# !pip install google-api-python-client

# %%
# Replace with your API key
api_key = 'AIzaSyDf5uvqrDxKGib7DgKMo5yYVcE-YJvacI8'

# Build YouTube API client
youtube = build('youtube', 'v3', developerKey=api_key)

# %%
video_id = '7zcsU1-OLxA'

# %%
video_id = '4LlxqjV4EKE'

# %%
def get_comments(video_id):
    comments = []
    next_page_token = None

    while True:
        response = youtube.commentThreads().list(
            part='snippet',
            videoId=video_id,
            maxResults=100,
            pageToken=next_page_token,
            textFormat='plainText'
        ).execute()

        for item in response['items']:
            comment = item['snippet']['topLevelComment']['snippet']
            comments.append({
                'author': comment['authorDisplayName'],
                'text': comment['textDisplay'],
                'likes': comment['likeCount'],
                'published_at': comment['publishedAt']
            })

        next_page_token = response.get('nextPageToken')
        if not next_page_token:
            break

    return pd.DataFrame(comments)

# %%
df = get_comments(video_id)

# %%
df.shape
# Out:
# (40729, 4)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 40746 entries, 38391 to 40728
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   text    40746 non-null  object
#  1   likes   40746 non-null  int64
#  2   Date    40746 non-null  object
#  3   Time    40746 non-null  object
# dtypes: int64(1), object(3)
# memory usage: 2.6+ MB

# %%
df.head()
# Out:
#               author                                               text  \
# 0       @dhruvrathee  🌏 Get an exclusive NordVPN deal here ➵  https:...
# 1    @malikilyas6156  In which indian city did Pakistan bomb the civ...
# 2   @nitinkanani8401                       aapni rotia banate rahe.....
# 3     @topburner1870                                       Love from 🇵🇰
# 4  @Amazing_clips562                                Love from Pakistan❤
#
#    likes          published_at
# 0   3181  2025-05-31T08:03:15Z
# 1      0  2025-06-08T12:09:51Z
# 2      0  2025-06-08T12:03:31Z
# 3      0  2025-06-08T11:57:45Z
# 4      0  2025-06-08T11:56:29Z

# %%
df
# Out:
#                      author  \
# 0              @dhruvrathee
# 1           @malikilyas6156
# 2          @nitinkanani8401
# 3            @topburner1870
# 4         @Amazing_clips562
# ...                     ...
# 40724       @razagaming9147
# 40725        @TaufeeqRaza77
# 40726       @KING_RIDER_110
# 40727  @rayyarizwankhan7178
# 40728           @Luca_Talis
#
#                                                     text  likes  \
# 0      🌏 Get an exclusive NordVPN deal here ➵  https:...   3181
# 1      In which indian city did Pakistan bomb the civ...      0
# 2                           aapni rotia banate rahe.....      0
# 3                                           Love from 🇵🇰      0
# 4                                    Love from Pakistan❤      0
# ...                                                  ...    ...
# 40724                                         Finally 🎉🔥      4
# 40725                                              First      1
# ...

# %%
df.to_csv('dhruv_rathee.csv')

# %%
df.sort_values(by='likes', ascending=False)
# Out:
#                     author                                               text  \
# 38374             @Basirsk  Mai ek Muslim hu aur main Garv karta hun ki ha...
# 38097        @RahulRawat4u                         Expose ANI in Next Video 🔥
# 40717  @shobhagorghate3571  ANI = Asian News📰 International \n❌\nANI = Alw...
# 37625            @nanang-o  Hi Dhruv Bhai,\n\nI’m Nanang reaching out from...
# 29033              @陽翔_海斗の                 私は日本人であり、テロとの戦いにおいてインドを支持します 🇯🇵🤝🇮🇳
# ...                    ...                                                ...
# 40693     @eyemateofficial                                                1st
# 40694           @Ayan_roxx                                                 😂😂
# 40695          @SaikotZayn                                              Vai❤❤
# 17         @NoreenDilarzoo                 People know this is your mind game
# 15         @bakrusoChaitom  Considering the public sentiment you're force ...
#
# ...

# %%
df['published_at'] = pd.to_datetime(df['published_at'])

df['Date'] = df['published_at'].dt.date
df['Time'] = df['published_at'].dt.time

# %%
df
# Out:
#                      author  \
# 0              @dhruvrathee
# 1           @malikilyas6156
# 2          @nitinkanani8401
# 3            @topburner1870
# 4         @Amazing_clips562
# ...                     ...
# 40724       @razagaming9147
# 40725        @TaufeeqRaza77
# 40726       @KING_RIDER_110
# 40727  @rayyarizwankhan7178
# 40728           @Luca_Talis
#
#                                                     text  likes  \
# 0      🌏 Get an exclusive NordVPN deal here ➵  https:...   3181
# 1      In which indian city did Pakistan bomb the civ...      0
# 2                           aapni rotia banate rahe.....      0
# 3                                           Love from 🇵🇰      0
# 4                                    Love from Pakistan❤      0
# ...                                                  ...    ...
# 40724                                         Finally 🎉🔥      4
# 40725                                              First      1
# ...

# %%
df.drop('published_at', axis=1, inplace=True)

# %%
df = df.sort_values(by='likes', ascending=False)

# %%
df
# Out:
#        Unnamed: 0                author  \
# 0               0          @dhruvrathee
# 1               1       @zahidboota8136
# 2               2      @binodkhadgi4533
# 3               3            @Daksh-p4n
# 4               4         @FarhadShohaz
# ...           ...                   ...
# 40741       40741       @razagaming9147
# 40742       40742        @TaufeeqRaza77
# 40743       40743       @KING_RIDER_110
# 40744       40744  @rayyarizwankhan7178
# 40745       40745           @Luca_Talis
#
#                                                     text  likes        Date  \
# 0      🌏 Get an exclusive NordVPN deal here ➵  https:...   3183  2025-05-31
# 1      Despite everything, you chose a side bro. You ...      0  2025-06-08
# 2                                                   😮😮😮😮      0  2025-06-08
# 3      Freedom of expression ka ye matlab nahi ki kis...      0  2025-06-08
# 4      I am from Balochistan, and I cherish truth abo...      0  2025-06-08
# ...

# %%
df['channel_id'] = youtube.search().list(part='snippet',q=df['author'],type='channel').execute()

# %%
df['subscriber_count'] = youtube.channels().list(part='statistics',id=df['channel_id']).execute()['items'][0]['statistics']['subscriberCount']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-23-1855e587845f> in <cell line: 0>()
# ----> 1 df['subscriber_count'] = youtube.channels().list(part='statistics',id=df['channel_id']).execute()['items'][0]['statistics']['subscriberCount']
#
# KeyError: 'items'

# %%
df.to_csv('dhruv_rathee2.csv')

# %%
chat_words = { "brb": "be right back","btw": "by the way","omg": "oh my god","lol": "laugh out loud","ttyl": "talk to you later","rofl": "rolling on the floor laughing","smh": "shaking my head","fyi": "for your information","lmao": "laughing my ass off","idk": "I don't know","fomo": "fear of missing out","gtg": "got to go","yolo": "you only live once","tbh": "to be honest","omw": "on my way","np": "no problem","brb": "be right back","wyd": "what are you doing","bff": "best friends forever","gtfo": "get the f*** out","ttys": "talk to you soon","asap": "as soon as possible","plz": "please","thx": "thanks","xoxo": "hugs and kisses","lmfao": "laughing my f***ing ass off","srsly": "seriously","cya": "see you","wbu": "what about you","bbl": "be back later","pov": "point of view","stfu": "shut the f*** up","mfw": "my face when","yass": "yes","tfw": "that feeling when","zomg": "oh my god","iykyk": "if you know you know"}

# %%
from googleapiclient.discovery import build
from indic_transliteration.sanscript import transliterate, ITRANS, DEVANAGARI
from langdetect import detect
import regex as re
import pandas as pd
import numpy as np
import emoji
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-7f00ee0b-1f2d-4de5-a930-7c06ca60bcc0" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-7f00ee0b-1f2d-4de5-a930-7c06ca60bcc0">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df = pd.read_csv('dhruv_rathee.csv')
df1 = df[['text', 'likes', 'Date', 'Time']]

df1['text'] = df1['text'].replace(r'^(nan|None)$', '', regex=True)
# Replace only real NaN (Not a Number), not the string "nan"
df1['text'] = df1['text'].fillna('')         # fills only actual NaN values
# Convert all values to string after that
df1['text'] = df1['text'].astype(str)

# Remove rows where 'text' is an empty string
df1 = df1[df1['text'].str.strip() != '']
df1.reset_index(drop=True, inplace=True)
df1 = df1.sort_values(by='likes', ascending=False, ignore_index=True)

df1['text'] = df1['text'].str.lower()

df1['text'] = df1['text'].apply(emoji.demojize)

def remove_HTML_tags(text):
    pattern = re.compile('<.*?>')
    return pattern.sub(r'', text) # Convert to string to handle potential non-string values
df1['text'] = df1['text'].apply(remove_HTML_tags) # Assign the result back to the column

def remove_url(text):
	pattern = re.compile(r'https://\S+|www\.\S+')
	return pattern.sub(r'', text)
# Here text can be any string
df1['text'] = df1['text'].apply(remove_url)

# import string
# exclude = string.punctuation
# def remove_punc1(text):
# 	return text.translate(str.maketrans('', '', exclude))
# df1['text'] = df1['text'].apply(remove_punc1)

def chat_conversion(text1):
  new_text = []
  for text in text1.strip().split('\n'):
    new_text1 = []
    for w in text.split():
      if w.upper() in chat_words:
        new_text1.append(chat_words[w.upper()])
      else:
        new_text1.append(w)
    new_text1 = " ".join(new_text1)
    new_text.append(new_text1)
  return "\n".join(new_text)
df1['text'] = df1['text'].apply(chat_conversion)
# Out:
# <ipython-input-3-755325638>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['text'] = df1['text'].replace(r'^(nan|None)$', '', regex=True)
# <ipython-input-3-755325638>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['text'] = df1['text'].fillna('')         # fills only actual NaN values
# <ipython-input-3-755325638>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
def replace_isolated_dots(text):
    text = text.replace('..', '.')
    # Find all positions of full stops in the text
    dot_indices = [m.start() for m in re.finditer(r'\.', text)]
    text_list = list(text)  # Convert to list for easy in-place editing

    for i in dot_indices:
        start = max(0, i - 5)
        end = min(len(text), i + 6)  # +6 to include the 5 characters after the dot
        neighborhood = text[start:i] + text[i+1:end]  # exclude the dot itself

        if '.' not in neighborhood:
            text_list[i] = '\n'  # Replace dot with newline

    return ''.join(text_list)

def replace_end_punc(line):
    line = line.replace('।', '\n')
    line = line.replace('?', '?\n')
    line = line.replace('!', '!\n')
    line = line.replace('\n\n', '\n')
    return line

df1['text'] = df1['text'].apply(replace_isolated_dots).apply(replace_end_punc)

# %%
sent_count = 0
word_count = 0
for text in df1['text']:
  para = text.split('\n')
  sent_count += len(para)
  for sent in para:
    word_count += len(sent.split())
print(sent_count)
print(word_count)
# Out:
# 73051
# 689530

# %%
df1.head()
# Out:
#                                                 text  likes        Date  \
# 0  mai ek muslim hu aur main garv karta hun ki ha...  25412  2025-05-31
# 1                    expose ani in next video :fire:  14004  2025-05-31
# 2  ani = asian news:newspaper: international\n:cr...  13583  2025-05-31
# 3  hi dhruv bhai,\ni’m nanang reaching out from a...  11311  2025-05-31
# 4  私は日本人であり、テロとの戦いにおいてインドを支持します :Japan::handshake...   3989  2025-05-31
#
#        Time
# 0  07:42:46
# 1  07:45:22
# 2  07:35:07
# 3  07:50:55
# 4  09:58:52

# %%
def df_info(df):
  sent_list = []
  for text in df['text']:
    for sent in text.strip().split('\n'):
      sent_list.append(sent)
  for sent in sent_list:
    print(sent)
df_info(df1)
# Out:
# Streaming output truncated to the last 5000 lines.
# तो मेरे सवाल का उत्तर दे तू:एन्रगेद्फ़चे::एन्रगेद्फ़चे::एन्रगेद्फ़चे:
# जब कोलकाता में हिंदू को ऊपर में हमला हुआ था
# तब तेरा वीडियो और तू कहांपर था
# जब बांग्लादेश में हिंदू के फैमिली में घुसकर मार रहा था
# तब तू कहां था
# साले देश में गंदगी फैला रहा है तू :एन्रगेद्फ़चे: अगर तेरी औकात है तो , मेरा सवाल का उत्तर जरूरदेना
# you are talking -ve point about modi is good,but you can also try to speek goods and real side of modi..!
# agar ap ye samjhta ho k pani band krna voilation of human rights ma ni ata to phr ap sai kahan pa ho?
# love from germany dhruv bro
# रात से आपका चैनल चेक कर रहा हु कोई वीडियो तो नहीं आया
# yr ya banda kia fazool batin kr rha hai jo batin last time ap na fazool bailin thi like 4 aker zameen kahrred li gai is trn ki on ka reply do baji :grinning_face_with_sweat:
# if india become war expert and latest technology will be worst than ever!
# india is really dangerous to its neighbour countries!
# ...

# %%
# Detect language safely
def detect_lang(text):
    try:
        lang = detect(text)
        return lang
    except:
        return None
# Check if sentence is in Devanagari script
def is_devanagari(text):
    result = bool(re.search(r'\p{Devanagari}', text))
    return result

# Check if sentence is in Latin (Roman) script
def is_latin(text):
    result = bool(re.search(r'\p{Latin}', text))
    return result
# Filter function
def keep_sentence(text):
    # lang = detect_lang(text)
    # if lang not in ['en', 'hi']:
    #     return False

    has_devanagari = is_devanagari(text)
    has_latin = is_latin(text)
    return has_devanagari or has_latin

def clean_text_block(text):
    lines = text.strip().split('\n')
    filtered = [line for line in lines if keep_sentence(line)]
    return '\n'.join(filtered)

# %%
df1['text'] = df1['text'].apply(clean_text_block)
df1 = df1[df1['text'].str.strip() != '']
df1.reset_index(drop=True, inplace=True)

# %%
def transliterate_to_devanagari(text):
    return transliterate(text, ITRANS, DEVANAGARI)

def transliterate_text_block(text):
    lines = text.strip().split('\n')
    new_lines = []
    for sent in lines:
        collection = sent.strip().split()
        for word in collection:
            counter = False
            if(is_devanagari(word)):
                counter = True
                break
        if(counter):
            new_collection = []
            for word in collection:
                if(is_latin(word) & (word.upper() != word)):
                    word = transliterate_to_devanagari(word)
                new_collection.append(word)
            new_collection = " ".join(new_collection)
            new_lines.append(new_collection)
        else:
            new_lines.append(sent)
    return "\n".join(new_lines)

df1['text'] = df1['text'].apply(transliterate_text_block)

# %%
from IPython.display import display, HTML
import difflib

def highlight_diff_html(str1, str2):
    d = difflib.Differ()
    diff = list(d.compare(str1, str2))

    result_html = ""
    for char in diff:
        if char.startswith('  '):
            result_html += char[2:]  # same character
        elif char.startswith('- '):
            result_html += f"<span style='color:red;font-weight:bold'>[-{char[2:]}]</span>"
        elif char.startswith('+ '):
            result_html += f"<span style='color:green;font-weight:bold'>[+{char[2:]}]</span>"

    display(HTML(f"<div style='font-family:monospace;font-size:16px'>{result_html}</div>"))

# %%
from textblob import TextBlob
for para in df1['text']:
  textBlb = TextBlob(para)
  para1 = textBlb.correct().string
  if(para1 != para):
    highlight_diff_html(para, para1)

# %%
# prompt: remove all '\n' substrings.

df1['text'] = df1['text'].str.replace('\n', '.', regex=False)

# %%
filtered_text_list = []
for text in df1['text']:
  text1 = text.split('\n')
  text1 = [s for s in text1 if keep_sentence(s)]
  filtered_text = "\n".join(text1)
  filtered_text_list.append(filtered_text)

# You might want to assign this back to a new column or overwrite the existing one
# For now, I will just print the first few filtered texts as an example
for i in range(min(5, len(filtered_text_list))):
  print(f"Original text: {df1['text'][i]}")
  print(f"Filtered text: {filtered_text_list[i]}")
  print("-" * 20)
# Out:
# Streaming output truncated to the last 5000 lines.
# Detected language for 'last me proof de hi diya ki ye mullo ka paidaish h...': sw
# Discarding due to language: sw
# Processing sentence: you are right 👍👍👍👍 brother...
# Detected language for 'you are right 👍👍👍👍 brother...': en
# Checking Devanagari for: you are right 👍👍👍👍 brother
# Devanagari result: False
# Checking Latin for: you are right 👍👍👍👍 brother
# Latin result: True
# Keeping: Pure Latin
# Processing sentence: please tell how many rafal shoot down...
# Detected language for 'please tell how many rafal shoot down...': en
# Checking Devanagari for: please tell how many rafal shoot down
# Devanagari result: False
# Checking Latin for: please tell how many rafal shoot down
# Latin result: True
# Keeping: Pure Latin
# Processing sentence: right 👍👍👍👍👍👍👍...
# Detected language for 'right 👍👍👍👍👍👍👍...': en
# Checking Devanagari for: right 👍👍👍👍👍👍👍
# Devanagari result: False
# Checking Latin for: right 👍👍👍👍👍👍👍
# Latin result: True
# ...

# %%
text = "isiliye bolate vakt jara dhyan rakhana.. modi ko desh ne choona hai, ek bar log galat ho sakate hai, lekin next time ki voting kam par huyi hai, india pahale se kafi age badha hai, lekin tuko modi ki koi baate aattchi lagati nahi.. tumhare vedeo sahi mudde par hoti hai, par jaroori nahi log sahmat ho.. modi was and is a great leader"

# %%
print(replace_isolated_dots(text))
# Out:
# isiliye bolate vakt jara dhyan rakhana
#  modi ko desh ne choona hai, ek bar log galat ho sakate hai, lekin next time ki voting kam par huyi hai, india pahale se kafi age badha hai, lekin tuko modi ki koi baate aattchi lagati nahi
#  tumhare vedeo sahi mudde par hoti hai, par jaroori nahi log sahmat ho
#  modi was and is a great leader

# %%
# !pip install inltk
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.1/40.1 kB 1.6 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.6/78.6 kB 3.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 233.3/233.3 kB 10.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 1.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 94.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 51.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 45.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 4.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 14.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 6.0 MB/s eta 0:00:00
# ...

# %%
from inltk.inltk import setup, get_sentence_similarity, predict_next_words, get_similar_sentences, correct_text

# Setup Hindi
setup('hi')

# Correct Hindi sentence
corrected = correct_text("मेे३रा नाअम अमीत हे", "hi")
print(corrected)  # Output: मेरा नाम अमित है
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-11-3739335364> in <cell line: 0>()
# ----> 1 from inltk.inltk import setup, get_sentence_similarity, predict_next_words, get_similar_sentences, correct_text
#       2
#       3 # Setup Hindi
#       4 setup('hi')
#       5
#
# ImportError: cannot import name 'correct_text' from 'inltk.inltk' (/usr/local/lib/python3.11/dist-packages/inltk/inltk.py)
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------
